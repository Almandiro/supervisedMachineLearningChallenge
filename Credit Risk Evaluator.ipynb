# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-13-d8c3d6795b4c> in <module>
#       1 train_df = pd.read_csv(Path('Resources/2019loans.csv'))
#       2 test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))
# ----> 3 merged_df = train_df.merge(test_df, left_on='index')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ...

# %%
# Convert categorical data to numeric and separate target feature for training data
train_get_df = pd.get_dummies(train_df, dummy_na=True)
train_get_df
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment  annual_inc  \
# 0           57107   57107    13375.0    0.1797       483.34    223000.0
# 1          141451  141451    21000.0    0.1308       478.68    123000.0
# 2          321143  321143    20000.0    0.1240       448.95    197000.0
# 3           11778   11778     3000.0    0.1240       100.22     45000.0
# 4          169382  169382    30000.0    0.1612      1056.49    133000.0
# ...           ...     ...        ...       ...          ...         ...
# 12175      354912  354912    19975.0    0.2565       801.09     28000.0
# 12176      354944  354944    15000.0    0.1774       540.34     50000.0
# 12177      354973  354973     3600.0    0.1862       131.28     60000.0
# 12178      355002  355002    15000.0    0.0881       475.68     62000.0
# 12179      355307  355307    15000.0    0.1774       540.34     54080.0
#
#          dti  delinq_2yrs  inq_last_6mths  open_acc  ...  \
# ...

# %%
# Convert categorical data to numeric and separate target feature for testing data
test_get_df = pd.get_dummies(test_df, dummy_na=True)
test_get_df
# Out:
#       Unnamed: 0  index  loan_amnt  int_rate  installment  annual_inc    dti  \
# 0          67991  67991    40000.0    0.0819       814.70    140000.0  19.75
# 1          25429  25429     6000.0    0.1524       208.70     55000.0  11.52
# 2          38496  38496     3600.0    0.1695       128.27     42000.0   6.74
# 3          19667  19667    20000.0    0.1524       478.33    100000.0  12.13
# 4          37505  37505     3600.0    0.1240       120.27     50000.0  16.08
# ...          ...    ...        ...       ...          ...         ...    ...
# 4697       77282  77282    30000.0    0.1240       673.42    140480.0  15.74
# 4698       77291  77291    24000.0    0.0756       747.22     50000.0  26.81
# 4699       77292  77292    10000.0    0.2305       387.36     33000.0  38.51
# 4700       77297  77297     8000.0    0.1862       205.86     38000.0  16.36
# 4701       77304  77304    30000.0    0.2055      1123.34    180000.0  12.06
#
# ...

# %%
# add missing dummy variables to testing set
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
test_get_df = imputer.fit_transform(test_get_df)
test_get_df
# Out:
# array([[6.7991e+04, 6.7991e+04, 4.0000e+04, ..., 0.0000e+00, 1.0000e+00,
#         0.0000e+00],
#        [2.5429e+04, 2.5429e+04, 6.0000e+03, ..., 0.0000e+00, 1.0000e+00,
#         0.0000e+00],
#        [3.8496e+04, 3.8496e+04, 3.6000e+03, ..., 0.0000e+00, 1.0000e+00,
#         0.0000e+00],
#        ...,
#        [7.7292e+04, 7.7292e+04, 1.0000e+04, ..., 0.0000e+00, 1.0000e+00,
#         0.0000e+00],
#        [7.7297e+04, 7.7297e+04, 8.0000e+03, ..., 0.0000e+00, 1.0000e+00,
#         0.0000e+00],
#        [7.7304e+04, 7.7304e+04, 3.0000e+04, ..., 0.0000e+00, 1.0000e+00,
#         0.0000e+00]])

# %%
# Train the Logistic Regression model on the unscaled data and print the model score

from sklearn.model_selection import train_test_split

merged_df = train_get_df.merge(test_get_df, left_on='index')

X = df.drop(['0', '1', '2', '3', '4', '5', 'X', 'C'], axis=1)
y = df[['0', '1', '2', '3', '4', '5', 'X', 'C']]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1053ecb2efce> in <module>
#       3 from sklearn.model_selection import train_test_split
#       4
# ----> 5 merged_df = train_get_df.merge(test_get_df, left_on='index')
#       6
#       7 X = df.drop(['0', '1', '2', '3', '4', '5', 'X', 'C'], axis=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
# ...

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
